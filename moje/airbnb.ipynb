# %%
import pandas as pd
import numpy as np
import missingno as msno
from jupyter_server.nbconvert.handlers import date_format

airbnb = pd.read_csv("../data/airbnb.csv")

# help(())

# %%
# airbnb.shape
# airbnb.head(5)
# airbnb.tail(5)
airbnb.info()
# airbnb.describe()
# airbnb.isnull().sum()
# airbnb.duplicated().sum()
# airbnb.describe()
# airbnb[~airbnb['price'].str.contains('$', regex=False)]
# airbnb[ (~airbnb['price'].str.contains('$', regex=False, na=False)) & (airbnb['price'].notna()) ]
# airbnb.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10019 entries, 0 to 10018
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          10019 non-null  int64
#  1   listing_id          10019 non-null  int64
#  2   name                10014 non-null  str
#  3   host_id             10019 non-null  int64
#  4   host_name           10017 non-null  str
#  5   neighbourhood_full  10019 non-null  str
#  6   coordinates         10019 non-null  str
#  7   room_type           10019 non-null  str
#  8   price               9781 non-null   str
#  9   number_of_reviews   10019 non-null  int64
#  10  last_review         7944 non-null   str
#  11  reviews_per_month   7944 non-null   float64
#  12  availability_365    10019 non-null  int64
#  13  rating              7944 non-null   float64
#  14  number_of_stays     7944 non-null   float64
#  15  5_stars             7944 non-null   float64
#  16  listing_added       10019 non-null  str
# dtypes: float64(4), int64(5), str(8)
# memory usage: 1.3 MB

# %%
# msno.matrix(airbnb)
# msno.bar(airbnb)
# msno.dendrogram(airbnb)

# %%
airbnb
# airbnb.isnull().sum()
# Out:
#        Unnamed: 0  listing_id  \
# 0               0    13740704
# 1               1    22005115
# 2               2    21667615
# 3               3     6425850
# 4               4    22986519
# ...           ...         ...
# 10014       10014    22307861
# 10015       10015      953275
# 10016       10016     3452835
# 10017       10017    23540194
# 10018       10018    32876011
#
#                                                     name    host_id host_name  \
# 0      Cozy,budget friendly, cable inc, private entra...   20583125    Michel
# 1                  Two floor apartment near Central Park   82746113   Cecilia
# 2                      Beautiful 1BR in Brooklyn Heights      78251    Leslie
# 3                              Spacious, charming studio   32715865    Yelena
# 4                  Bedroom on the lively Lower East Side  154262349    Brooke
# ...                                                  ...        ...       ...
# 10014                        Lovely 1BR Harlem apartment   16004068    Rachel
# 10015                Apartment For Your Holidays in NYC!    4460034     Alain
# 10016          Artsy, Garden Getaway in Central Brooklyn     666862       Amy
# 10017     Immaculate townhouse in Clinton Hill, Brooklyn   67176930    Sophie
# 10018     Private room in a perfect location in the city   59583716      Shai
#
#                neighbourhood_full                     coordinates  \
# 0             Brooklyn, Flatlands           (40.63222, -73.93398)
# 1      Manhattan, Upper West Side           (40.78761, -73.96862)
# 2      Brooklyn, Brooklyn Heights            (40.7007, -73.99517)
# 3      Manhattan, Upper West Side           (40.79169, -73.97498)
# 4      Manhattan, Lower East Side           (40.71884, -73.98354)
# ...                           ...                             ...
# 10014           Manhattan, Harlem           (40.80379, -73.95257)
# 10015      Manhattan, East Harlem            (40.79531, -73.9333)
# 10016      Brooklyn, Clinton Hill  (40.68266, -73.96743000000002)
# 10017      Brooklyn, Clinton Hill           (40.68832, -73.96366)
# 10018  Manhattan, Upper East Side           (40.76174, -73.96625)
#
#              room_type price  number_of_reviews last_review  \
# 0         Private room   45$                 10  2018-12-12
# 1      Entire home/apt  135$                  1  2019-06-30
# 2      Entire home/apt  150$                  0         NaN
# 3      Entire home/apt   86$                  5  2017-09-23
# 4         Private room  160$                 23  2019-06-12
# ...                ...   ...                ...         ...
# 10014  Entire home/apt  105$                  4  2018-05-28
# 10015  Entire home/apt  125$                 50  2018-05-06
# 10016  Entire home/apt  100$                 45  2016-11-27
# 10017  Entire home/apt  450$                  2  2019-05-31
# 10018     Private room   90$                  1  2019-03-12
#
#        reviews_per_month  availability_365    rating  number_of_stays  \
# 0                   0.70                85  4.100954             12.0
# 1                   1.00               145  3.367600              1.2
# 2                    NaN                65       NaN              NaN
# 3                   0.13                 0  4.763203              6.0
# 4                   2.29               102  3.822591             27.6
# ...                  ...               ...       ...              ...
# 10014               0.21                 0  4.757555              4.8
# 10015               0.66               188  4.344704             60.0
# 10016               0.98                 0  3.966214             54.0
# 10017               0.17                99  4.078581              2.4
# 10018               0.25                 8  4.069096              1.2
#
#         5_stars listing_added
# 0      0.609432    2018-06-08
# 1      0.746135    2018-12-25
# 2           NaN    2018-08-15
# 3      0.769947    2017-03-20
# 4      0.649383    2020-10-23
# ...         ...           ...
# 10014  0.639223    2017-11-22
# 10015  0.648778    2017-10-31
# 10016  0.631713    2016-05-24
# 10017  0.703360    2018-11-25
# 10018  0.720249    2018-09-06
#
# [10019 rows x 17 columns]

# %% [markdown]
# # Plan Czyszczenia Zbioru Danych (Airbnb)
#
# ## Faza 1: Zrzucenie Balastu (Quick Wins)
# W tej fazie pozbywamy się śmieci, które tylko zżerają pamięć i zaburzają statystyki.
# - [ ] **Usunięcie bezużytecznych kolumn:** Wyrzucenie kolumny `Unnamed: 0` (pozostałość po starym indeksie).
# - [ ] **Usunięcie klonów:** Sprawdzenie i usunięcie zduplikowanych wierszy w skali 1:1 (ta sama oferta skopiowana dwa razy).
#
# ## Faza 2: Transformacja Typów Danych (Rzutowanie)
# W tej fazie zmuszamy Pandas do poprawnego rozumienia liczb i dat.
# - [ ] **`price`:** Wycięcie symbolu waluty (`$`) i konwersja kolumny ze zmiennej tekstowej na liczbową (`float`).
# - [ ] **`number_of_stays`:** Konwersja na liczby całkowite (`int`) – usunięcie wartości po przecinku.
# - [ ] **`listing_added` & `last_review`:** Konwersja ze zwykłego tekstu na format daty (`datetime`).
#
# ## Faza 3: Inżynieria Cech (Rozbijanie tekstu)
# W tej fazie wyciągamy użyteczne informacje z brudnych ciągów znaków.
# - [ ] **`coordinates`:** Rozbicie nawiasu i podział na dwie osobne kolumny numeryczne: `latitude` i `longitude`.
# - [ ] **`neighbourhood_full`:** Rozdzielenie tekstu po przecinku na dwie nowe kolumny: `city` oraz `neighbourhood`.
# - [ ] **`room_type`:** Ujednolicenie kategorii (np. "private room" i "private" -> jedna nazwa).
#
# ## Faza 4: Obsługa Braków Danych (Missing Values)
# W tej fazie łatamy dziury w bazie.
# - [ ] **Weryfikacja 2075 braków:** Sprawdzenie, czy braki w ocenach wynikają z braku recenzji (`number_of_reviews == 0`).
# - [ ] **Uzupełnianie luk:** Decyzja o uzupełnieniu lub usunięciu braków w `price` (238), `name` (5) i `host_name` (2).
#
# ## Faza 5: Walidacja Logiki Biznesowej (Sanity Checks)
# W tej fazie sprawdzamy, czy dane nie łamią praw fizyki i logiki ekonomicznej.
# - [ ] **Test kalendarza:** Sprawdzenie `availability_365` pod kątem wartości ujemnych lub > 365.
# - [ ] **Test chronologii:** Sprawdzenie, czy `last_review` nie jest starsze niż `listing_added`.
# - [ ] **Test skali ocen:** Sprawdzenie, czy `rating` i `5_stars` mieszczą się w poprawnym przedziale (np. 1-5).

# %% [markdown]
# ## Faza 1 dropy

# %%
airbnb = airbnb.drop(columns=['Unnamed: 0'] , errors='ignore')
airbnb = airbnb.drop_duplicates()

# %% [markdown]
# ## Faza 2 transformacja typów

# %%
airbnb['price'] = airbnb['price'].str.replace('$', '', regex=False).astype('float64')
airbnb['number_of_stays'] = airbnb['number_of_stays'].astype('Int64')
airbnb['listing_added'] = pd.to_datetime(airbnb['listing_added'])
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])
# print(airbnb[['price', 'number_of_stays', 'listing_added', 'last_review']].dtypes)
# airbnb
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\arrays\integer.py:63, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      62 try:
# ---> 63     return values.astype(dtype, casting="safe", copy=copy)
#      64 except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int64') according to the rule 'safe'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 airbnb['price'] = airbnb['price'].str.replace('$', '', regex=False).astype('float64')
# ----> 2 airbnb['number_of_stays'] = airbnb['number_of_stays'].astype('Int64')
#       3 airbnb['listing_added'] = pd.to_datetime(airbnb['listing_added'])
#       4 airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:81, in _astype_nansafe(arr, dtype, copy, skipna)
#      79 # dispatch on extension dtype if needed
#      80 if isinstance(dtype, ExtensionDtype):
# ---> 81     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      83 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      84     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\arrays\masked.py:161, in BaseMaskedArray._from_sequence(cls, scalars, dtype, copy)
#     159 @classmethod
#     160 def _from_sequence(cls, scalars, *, dtype=None, copy: bool = False) -> Self:
# --> 161     values, mask = cls._coerce_to_array(scalars, dtype=dtype, copy=copy)
#     162     return cls(values, mask)
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\arrays\numeric.py:293, in NumericArray._coerce_to_array(cls, value, dtype, copy)
#     288 @classmethod
#     289 def _coerce_to_array(
#     290     cls, value, *, dtype: DtypeObj, copy: bool = False
#     291 ) -> tuple[np.ndarray, np.ndarray]:
#     292     dtype_cls = cls._dtype_cls
# --> 293     values, mask = _coerce_to_data_and_mask(value, dtype, copy, dtype_cls)
#     294     return values, mask
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\arrays\numeric.py:248, in _coerce_to_data_and_mask(values, dtype, copy, dtype_cls)
#     246     values = values.astype(dtype, copy=copy)
#     247 else:
# --> 248     values = dtype_cls._safe_cast(values, dtype, copy=False)
#     249 return values, mask
#
# File ~\PycharmProjects\Data_Analysis_Workshops\.venv\Lib\site-packages\pandas\core\arrays\integer.py:69, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      66 if (casted == values).all():
#      67     return casted
# ---> 69 raise TypeError(
#      70     f"cannot safely cast non-equivalent {values.dtype} to {np.dtype(dtype)}"
#      71 ) from err
#
# TypeError: cannot safely cast non-equivalent float64 to int64

# %% [markdown]
# ## Faza 3  rozbijanie i poprawianie  danych

# %%
airbnb[['latitude', 'longitude']] = airbnb['coordinates'].str.strip('()').str.split(', ', expand=True).astype(float)
airbnb[['town','district']] = airbnb['neighbourhood_full'].str.split(', ' , expand=True)
airbnb['room_type'] = airbnb['room_type'].replace('private', 'Private room')
airbnb['room_type'] = airbnb['room_type'].replace('Private', 'Private room')
airbnb['room_type'] = airbnb['room_type'].replace('PRIVATE ROOM', 'Private room')
airbnb['room_type'] = airbnb['room_type'].replace('   Shared room      ', 'Shared room')
airbnb = airbnb.drop(columns=['coordinates', 'neighbourhood_full'])
airbnb['room_type'].unique()
# Out:
# <StringArray>
# ['Private room', 'Entire home/apt', 'Shared room', 'home']
# Length: 4, dtype: str

# %% [markdown]
# ## Faza 4 obsługa Nan

# %%
# airbnb[airbnb['name'].isna()]
airbnb = airbnb.dropna(subset=['name', 'host_name'])
mediana_dzielnicy = airbnb.groupby(['town' , 'district'])['price'].transform('median')
airbnb['price'] = airbnb['price'].fillna(mediana_dzielnicy)
mediana_dzielnicy = airbnb.groupby(['town'])['price'].transform('median')
airbnb['price'] = airbnb['price'].fillna(mediana_dzielnicy)
airbnb['visited'] = airbnb['last_review'] > airbnb['listing_added']
kolumny_numeryczne = ['reviews_per_month', 'rating', 'number_of_stays', '5_stars']
airbnb[kolumny_numeryczne] = airbnb[kolumny_numeryczne].fillna(0)
# airbnb[~airbnb.isna().any(axis=1)]
airbnb
# Out:
#        listing_id                                               name  \
# 0        13740704  Cozy,budget friendly, cable inc, private entra...
# 1        22005115              Two floor apartment near Central Park
# 2        21667615                  Beautiful 1BR in Brooklyn Heights
# 3         6425850                          Spacious, charming studio
# 4        22986519              Bedroom on the lively Lower East Side
# ...           ...                                                ...
# 10014    22307861                        Lovely 1BR Harlem apartment
# 10015      953275                Apartment For Your Holidays in NYC!
# 10016     3452835          Artsy, Garden Getaway in Central Brooklyn
# 10017    23540194     Immaculate townhouse in Clinton Hill, Brooklyn
# 10018    32876011     Private room in a perfect location in the city
#
#          host_id host_name        room_type  price  number_of_reviews  \
# 0       20583125    Michel     Private room   45.0                 10
# 1       82746113   Cecilia  Entire home/apt  135.0                  1
# 2          78251    Leslie  Entire home/apt  150.0                  0
# 3       32715865    Yelena  Entire home/apt   86.0                  5
# 4      154262349    Brooke     Private room  160.0                 23
# ...          ...       ...              ...    ...                ...
# 10014   16004068    Rachel  Entire home/apt  105.0                  4
# 10015    4460034     Alain  Entire home/apt  125.0                 50
# 10016     666862       Amy  Entire home/apt  100.0                 45
# 10017   67176930    Sophie  Entire home/apt  450.0                  2
# 10018   59583716      Shai     Private room   90.0                  1
#
#       last_review  reviews_per_month  availability_365    rating  \
# 0      2018-12-12               0.70                85  4.100954
# 1      2019-06-30               1.00               145  3.367600
# 2             NaN               0.00                65  0.000000
# 3      2017-09-23               0.13                 0  4.763203
# 4      2019-06-12               2.29               102  3.822591
# ...           ...                ...               ...       ...
# 10014  2018-05-28               0.21                 0  4.757555
# 10015  2018-05-06               0.66               188  4.344704
# 10016  2016-11-27               0.98                 0  3.966214
# 10017  2019-05-31               0.17                99  4.078581
# 10018  2019-03-12               0.25                 8  4.069096
#
#        number_of_stays   5_stars listing_added  latitude  longitude  \
# 0                 12.0  0.609432    2018-06-08  40.63222  -73.93398
# 1                  1.2  0.746135    2018-12-25  40.78761  -73.96862
# 2                  0.0  0.000000    2018-08-15  40.70070  -73.99517
# 3                  6.0  0.769947    2017-03-20  40.79169  -73.97498
# 4                 27.6  0.649383    2020-10-23  40.71884  -73.98354
# ...                ...       ...           ...       ...        ...
# 10014              4.8  0.639223    2017-11-22  40.80379  -73.95257
# 10015             60.0  0.648778    2017-10-31  40.79531  -73.93330
# 10016             54.0  0.631713    2016-05-24  40.68266  -73.96743
# 10017              2.4  0.703360    2018-11-25  40.68832  -73.96366
# 10018              1.2  0.720249    2018-09-06  40.76174  -73.96625
#
#             town          district  visited
# 0       Brooklyn         Flatlands     True
# 1      Manhattan   Upper West Side     True
# 2       Brooklyn  Brooklyn Heights    False
# 3      Manhattan   Upper West Side     True
# 4      Manhattan   Lower East Side    False
# ...          ...               ...      ...
# 10014  Manhattan            Harlem     True
# 10015  Manhattan       East Harlem     True
# 10016   Brooklyn      Clinton Hill     True
# 10017   Brooklyn      Clinton Hill     True
# 10018  Manhattan   Upper East Side     True
#
# [9999 rows x 19 columns]

# %% [markdown]
# ## Faza 5 walidacja

# %%
bledne_daty = airbnb[(airbnb['last_review'] < airbnb['listing_added'])]
print(f"Błędy w datach: {len(bledne_daty)}")
bledny_kalendarz = airbnb[(airbnb['availability_365'] < 0) | (airbnb['availability_365'] > 365)]
print(f"Błędy w dostępności: {len(bledny_kalendarz)}")
bledne_oceny = airbnb[(airbnb['rating']  < 0) | (airbnb['rating'] > 5)]
print(f"Błędy w ocenach (rating): {len(bledne_oceny)}")
bledne_5_stars = airbnb[(airbnb['5_stars'] < 0.0) | (airbnb['5_stars'] > 1.0)]
print(f"Błędy w odsetku 5 gwiazdek: {len(bledne_5_stars)}")
bledne_ceny = airbnb[(airbnb['price'] <= 0)]
print(f"Błędy w  cenach: {len(bledne_ceny)}")
bledne_ilosc_ocen = airbnb[(airbnb['number_of_reviews'] < 0)]
print(f"Błędy w  ilosci ocen: {len(bledne_ilosc_ocen)}")
# Out:
# Błędy w datach: 6
# Błędy w dostępności: 0
# Błędy w ocenach (rating): 3
# Błędy w odsetku 5 gwiazdek: 0
# Błędy w  cenach: 2
# Błędy w  ilosci ocen: 0

# %%
airbnb = airbnb.drop(index=bledne_daty.index)
airbnb = airbnb.drop(index=bledne_oceny.index)
airbnb = airbnb.drop(index=bledne_ceny.index)
# airbnb['last_review'] = airbnb['last_review'].fillna(pd.to_datetime('1970-01-01'))
airbnb.to_csv('airbnb_clean.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 airbnb = airbnb.drop(index=bledne_daty.index)
#       2 airbnb = airbnb.drop(index=bledne_oceny.index)
#       3 airbnb = airbnb.drop(index=bledne_ceny.index)
#
# NameError: name 'airbnb' is not defined
